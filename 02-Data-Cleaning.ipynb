# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.Max_rows', None)
import warnings
warnings.filterwarnings('ignore')

# %%
sales = pd.read_csv('sales.csv')

# %%
sales.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2522    2523  CA-2017-124352  15/10/2017  21/10/2017  Standard Class
# 5916    5917  US-2016-126977  17/09/2016  23/09/2016  Standard Class
# 5725    5726  CA-2016-103933  25/09/2016  27/09/2016     First Class
# 2553    2554  CA-2017-155439  14/09/2017  18/09/2017  Standard Class
# 5926    5927  US-2015-118997  08/04/2015  12/04/2015  Standard Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 2522    CD-12790  Cynthia Delaney  Home Office  United States  Oklahoma City
# 5916    PF-19120     Peter Fuller     Consumer  United States  New York City
# 5725    DR-12880  Dan Reichenbach    Corporate  United States  New York City
# 2553    PN-18775   Parhena Norris  Home Office  United States       Columbia
# 5926    RA-19885     Ruben Ausman    Corporate  United States        Decatur
#
#                State  Postal Code   Region       Product ID         Category  \
# ...

# %% [markdown]
# ### Copy

# %%
df = sales.copy()

# %% [markdown]
# ### Drop irrelevant Cols

# %%
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3787    3788  CA-2017-169971  04/09/2017  09/09/2017  Standard Class
# 2025    2026  CA-2016-114237  13/03/2016  15/03/2016     First Class
# 9429    9430  CA-2016-166219  28/08/2016  01/09/2016  Standard Class
# 8966    8967  CA-2017-134180  03/11/2017  07/11/2017  Standard Class
# 9573    9574  CA-2016-113131  24/09/2016  24/09/2016        Same Day
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 3787    IL-15100      Ivan Liston     Consumer  United States       Houston
# 2025    MC-17275       Marc Crier     Consumer  United States       Seattle
# 9429    BP-11185     Ben Peterman    Corporate  United States        Dallas
# 8966    JP-16135   Julie Prescott  Home Office  United States  Philadelphia
# 9573    MB-17305  Maria Bertelson     Consumer  United States      Columbus
#
#              State  Postal Code   Region       Product ID         Category  \
# ...

# %%
cols_to_drop = ['Row ID', 'Order ID', 'Customer ID', 'Customer Name', 'Product ID', 'Product Name']
df.drop(columns = cols_to_drop, inplace = True)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    9800 non-null   object
#  1   Ship Date     9800 non-null   object
#  2   Ship Mode     9800 non-null   object
#  3   Segment       9800 non-null   object
#  4   Country       9800 non-null   object
#  5   City          9800 non-null   object
#  6   State         9800 non-null   object
#  7   Postal Code   9789 non-null   float64
#  8   Region        9800 non-null   object
#  9   Category      9800 non-null   object
#  10  Sub-Category  9800 non-null   object
#  11  Sales         9800 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 918.9+ KB

# %% [markdown]
# ### export data to excel for manual assessment

# %%
df.to_excel('sales.xlsx', index = False)

# %% [markdown]
# ### Issue with dataset
# - `Postal Code` contain missing values.
# - Contain duplicate values.

# %%
df.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment        Country  \
# 0  08/11/2017  11/11/2017    Second Class   Consumer  United States
# 1  08/11/2017  11/11/2017    Second Class   Consumer  United States
# 2  12/06/2017  16/06/2017    Second Class  Corporate  United States
# 3  11/10/2016  18/10/2016  Standard Class   Consumer  United States
# 4  11/10/2016  18/10/2016  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky      42420.0  South        Furniture
# 1        Henderson    Kentucky      42420.0  South        Furniture
# 2      Los Angeles  California      90036.0   West  Office Supplies
# 3  Fort Lauderdale     Florida      33311.0  South        Furniture
# 4  Fort Lauderdale     Florida      33311.0  South  Office Supplies
#
#   Sub-Category     Sales
# 0    Bookcases  261.9600
# 1       Chairs  731.9400
# 2       Labels   14.6200
# 3       Tables  957.5775
# ...

# %%
# check for duplicate
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
# check for null values
df.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code     11
# Region           0
# Category         0
# Sub-Category     0
# Sales            0
# dtype: int64

# %%
# stats description
df.describe()
# Out:
#         Postal Code         Sales
# count   9789.000000   9800.000000
# mean   55273.322403    230.769059
# std    32041.223413    626.651875
# min     1040.000000      0.444000
# 25%    23223.000000     17.248000
# 50%    58103.000000     54.490000
# 75%    90008.000000    210.605000
# max    99301.000000  22638.480000

# %% [markdown]
# ### Drop duplicated values

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Postal Code

# %%
df['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035.0    253
# 10024.0    225
# 10009.0    220
# 94122.0    195
# 10011.0    193
# 94110.0    166
# 98105.0    165
# 19134.0    160
# 90049.0    150
# 98103.0    149
# 19140.0    149
# 94109.0    139
# 90045.0    136
# 90036.0    122
# 43229.0    119
# 90004.0    117
# 77041.0    114
# 19143.0    114
# 98115.0    112
# 19120.0    109
# 60610.0    108
# 77095.0    104
# 90008.0    102
# 60623.0    101
# 90032.0    101
# 60653.0     99
# 77070.0     91
# 32216.0     75
# 92105.0     74
# 31907.0     67
# 77036.0     65
# 85023.0     63
# 92037.0     62
# 78207.0     59
# 19711.0     57
# 75217.0     55
# 75220.0     53
# 48227.0     51
# 28205.0     51
# 28540.0     50
# 22153.0     50
# 75081.0     48
# 42420.0     48
# 80219.0     44
# 21215.0     43
# 95123.0     42
# 53209.0     40
# 65807.0     39
# 30318.0     39
# 92024.0     39
# 78745.0     39
# 97477.0     38
# 49201.0     38
# 44105.0     38
# 48234.0     36
# 33614.0     36
# 14609.0     36
# 43055.0     35
# ...

# %%
df[df['Postal Code'].isnull()]
# Out:
#       Order Date   Ship Date       Ship Mode      Segment        Country  \
# 2234  05/12/2018  10/12/2018  Standard Class    Corporate  United States
# 5274  07/11/2016  09/11/2016    Second Class     Consumer  United States
# 8798  06/04/2017  10/04/2017  Standard Class  Home Office  United States
# 9146  23/01/2017  27/01/2017  Standard Class    Corporate  United States
# 9147  23/01/2017  27/01/2017  Standard Class    Corporate  United States
# 9148  23/01/2017  27/01/2017  Standard Class    Corporate  United States
# 9386  19/01/2018  23/01/2018  Standard Class     Consumer  United States
# 9387  19/01/2018  23/01/2018  Standard Class     Consumer  United States
# 9388  19/01/2018  23/01/2018  Standard Class     Consumer  United States
# 9389  19/01/2018  23/01/2018  Standard Class     Consumer  United States
# 9741  08/11/2016  12/11/2016  Standard Class    Corporate  United States
#
#             City    State  Postal Code Region         Category Sub-Category  \
# ...

# %%
# Postal code of United States Burlington Vermont is 05402
df['Postal Code'].fillna(0o5402, inplace = True)

# %%
# check
df.isnull().sum()
# Out:
# Order Date      0
# Ship Date       0
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# dtype: int64

# %% [markdown]
# ### Export cleanned dataset

# %%
df.to_csv('cleaned-sales.csv', index = False)
