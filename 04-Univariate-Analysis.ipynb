# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
pd.set_option('display.Max_rows', None)

# %%
df = pd.read_csv('processed-salesdata.csv')

# %%
df.sample(5)
# Out:
#            Ship Mode   Segment        Country         City         State  \
# 344   Standard Class  Consumer  United States       Austin         Texas
# 8177  Standard Class  Consumer  United States  Springfield        Oregon
# 9380    Second Class  Consumer  United States        Tampa       Florida
# 4205    Second Class  Consumer  United States     Cranston  Rhode Island
# 4447  Standard Class  Consumer  United States  Los Angeles    California
#
#       Postal Code   Region         Category Sub-Category    Sales Order Month  \
# 344         78745  Central  Office Supplies      Storage   88.800    December
# 8177        97477     West        Furniture       Tables  277.500      August
# 9380        33614    South  Office Supplies          Art    1.344    December
# 4205         2920     East        Furniture  Furnishings   17.670     October
# 4447        90032     West  Office Supplies        Paper    6.480        June
#
#       Order Day  Ship day
# 344     Tuesday  Saturday
# ...

# %%
# check for duplicated
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Order Month     0
# Order Day       0
# Ship day        0
# dtype: int64

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9798 entries, 0 to 9797
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9798 non-null   object
#  1   Segment       9798 non-null   object
#  2   Country       9798 non-null   object
#  3   City          9798 non-null   object
#  4   State         9798 non-null   object
#  5   Postal Code   9798 non-null   int64
#  6   Region        9798 non-null   object
#  7   Category      9798 non-null   object
#  8   Sub-Category  9798 non-null   object
#  9   Sales         9798 non-null   float64
#  10  Order Month   9798 non-null   object
#  11  Order Day     9798 non-null   object
#  12  Ship day      9798 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 995.2+ KB

# %% [markdown]
# ## 1. Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5858
# Second Class      1901
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Ship Mode'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Ship Mode'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - Standard Class is the majority, for 59.8% of the total.

# %% [markdown]
# ## 2. Segment

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5101
# Corporate      2952
# Home Office    1745
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Segment'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Segment'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observations
# - Most of the business comes from regular consumers
# - The Consumer segment is the largest, making up 52.1% of the total

# %% [markdown]
# ## 3. Country

# %%
df['Country'].value_counts()
# Out:
# Country
# United States    9798
# Name: count, dtype: int64

# %% [markdown]
# Dataset consist of United States, Superstore sales

# %% [markdown]
# ## 4. City

# %%
df['City'].value_counts()
# Out:
# City
# New York City        891
# Los Angeles          728
# Philadelphia         532
# San Francisco        500
# Seattle              426
# Houston              374
# Chicago              308
# Columbus             220
# San Diego            170
# Springfield          161
# Dallas               156
# Jacksonville         125
# Detroit              115
# Newark                92
# Jackson               82
# Columbia              81
# Richmond              81
# Aurora                68
# Phoenix               63
# Arlington             60
# San Antonio           59
# Miami                 56
# Louisville            54
# Rochester             53
# Long Beach            52
# Charlotte             51
# Henderson             51
# Lakewood              48
# Lancaster             46
# Lawrence              44
# Denver                44
# Baltimore             43
# Fairfield             42
# San Jose              42
# Pasadena              42
# Fayetteville          41
# ...

# %%
plt.figure(figsize = (13, 5))
df['City'].value_counts().head(20).plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['City'].value_counts().head(10).plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - New York City has the highest percentage of orders, 20.7% of the total.

# %% [markdown]
# ## 5. State

# %%
df['State'].value_counts()
# Out:
# State
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     453
# Florida                  373
# Michigan                 253
# North Carolina           247
# Arizona                  223
# Virginia                 223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Indiana                  135
# Massachusetts            135
# Oregon                   122
# New Jersey               122
# Maryland                 105
# Wisconsin                105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize = (13, 5))
df['State'].value_counts().head(20).plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['State'].value_counts().head(10).plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %%
percentage_state_order = df['State'].value_counts(normalize = True) * 100
(percentage_state_order < 1).sum()
# Out:
# np.int64(27)

# %% [markdown]
# ### Observation
# - California has the highest percentage of orders, 28.2% of the total.
# - 27 other state has less than 1% orders.

# %% [markdown]
# ## 6. Region

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3140
# East       2784
# Central    2277
# South      1597
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Region'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Region'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - West Region of United States have ordered the most.
# - Western and Eastern regions have similar percentages of orders.

# %% [markdown]
# ## 7. Category

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    5908
# Furniture          2077
# Technology         1813
# Name: count, dtype: int64

# %%
df['Category'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - Office Supplies covers the more orders.
# - Technology is least ordered.

# %% [markdown]
# ## 8. Sub-Category

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             784
# Accessories     756
# Chairs          606
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Sub-Category'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Sub-Category'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - Binders, Paper are the most ordered things, as they are office supplies and we know office supplies are the most orderred about 60%

# %% [markdown]
# ## 9. Sales

# %%
df['Sales'].describe()
# Out:
# count     9798.000000
# mean       230.785104
# std        626.712110
# min          0.444000
# 25%         17.248000
# 50%         54.490000
# 75%        210.576000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
plt.figure(figsize = (13, 5))
df['Sales'].value_counts().plot(kind = 'hist', bins = [0, 10, 20, 30])
plt.show()

# %%
plt.figure(figsize = (13, 5))
sns.boxenplot(y = df['Sales'])
plt.show()

# %%
plt.figure(figsize = (13, 5))
sns.boxplot(y = df['Sales'])
plt.show()

# %%
plt.figure(figsize = (13, 5))
sns.histplot(df['Sales'], kde = True)
plt.show()

# %%
df['Sales'].skew()
# Out:
# np.float64(12.982316721948633)

# %% [markdown]
# ### Observation
# - Sales column contain significant outliers.
# - Skewness is highly positive atleast 12.9%, a solid proof that its contain outliers.

# %% [markdown]
# ## 10. Order Month

# %%
df['Order Month'].value_counts()
# Out:
# Order Month
# November     1449
# December     1382
# September    1354
# October       809
# May           725
# July          697
# August        693
# June          691
# March         680
# April         655
# January       366
# February      297
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Order Month'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Order Month'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - November, December, and September are the top three months for orders, indicating business activity in the third and fourth quarters.
# - The year begins with its lowest, with January and February showing the least order activity.

# %% [markdown]
# ## 11. Order Day

# %%
df['Order Day'].value_counts()
# Out:
# Order Day
# Tuesday      1889
# Saturday     1786
# Sunday       1694
# Monday       1593
# Wednesday    1229
# Friday       1067
# Thursday      540
# Name: count, dtype: int64

# %%
plt.figure(figsize = (13, 5))
df['Order Day'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize = (13, 5))
df['Order Day'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ### Observation
# - Tuesday is the day with the most orders.
# - Thursday looking outlier as it dropped to 5.5%.

# %% [markdown]
# ## 12. Ship day

# %%
df['Ship day'].value_counts()
# Out:
# Ship day
# Thursday     1564
# Saturday     1498
# Sunday       1474
# Wednesday    1433
# Friday       1420
# Monday       1235
# Tuesday      1174
# Name: count, dtype: int64
